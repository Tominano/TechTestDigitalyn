# %% [markdown]
# # Task 1: Visualization with seaborn and pandas.
#
# Load the solar_mesh.csv file as a dataframe with pandas. In the file the first row and the first colum show binned coordinates (over germany). Your task is to graph a heatmap with the weights being the values withing those coordinates (or coordinate bins). (preferabily with seaborn)
#
# As an example at the coordinate bin (47.511, 47.601], (6.061, 6.219], the weight should be 0, but at (50.743, 50.825], (6.061, 6.219] the weight should be 7720. For bonus points you can normalize all the weights.

# %%
from IPython.core.display import HTML # For the HTML language

import warnings
warnings.filterwarnings('ignore') # Against the error messages of the multiple imports.

# %%
# Here is a short code to hide the codes blocks to see just the images.
# An .HTML file looks better/cleaner if you turn on this. 
HTML('''<script>
code_show=true;
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
}
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit"
value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit"
# value="Click here to toggle on/off the raw code."></form>

# %%
#import the packages what we need
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../solar_mesh.csv',index_col=0) 
# We can simply read the file with pandas, fortunately is in the manageable form,
# we have to set the first collumn to index collumn with "index_col=0".
# We can set the new index for the plot as df = df.set_index('bins_lat') but the first line is more formal.

# %%
#df # Just check the dataset, how it looks.

# %%
#df.index.name = 'Longitude'

# %%
#df_i = df_i.pivot_table()

# %%
fig, ax = plt.subplots(figsize=(15,15))
ax = sns.heatmap(df, cmap='viridis') # Here is the Heatmap plot
plt.title('Weights in Germany\n based on binned cordinates', fontsize = 20) # title with fontsize 20
plt.xlabel('Latitudes', fontsize = 15) # x-axis label with fontsize 15
plt.ylabel('Longitudes', fontsize = 15) # y-axis label with fontsize 15
# Out:
# Text(114.0, 0.5, 'Longitudes')

# %%
column_maxes = df.max()
df_max = column_maxes.max()
normalized_df = df / df_max

# %%
fig, ax = plt.subplots(figsize=(15,15))
ax = sns.heatmap(normalized_df, cmap = 'viridis') # Here is the Heatmap plot
plt.title('Weights in Germany\n based on binned cordinates', fontsize = 20) # title with fontsize 20
plt.xlabel('Latitudes', fontsize = 15) # x-axis label with fontsize 15
plt.ylabel('Longitudes', fontsize = 15) # y-axis label with fontsize 15
# Out:
# Text(114.0, 0.5, 'Longitudes')

# %%
normalized_dff=(df-df.mean())/df.std()

# %%
fig, ax = plt.subplots(figsize=(15,15))
ax = sns.heatmap(normalized_dff, cmap='viridis') # Here is the Heatmap plot
#ax = sns.heatmap(normalized_dff, cmap='viridis',vmin = 0, vmax = 1) # Here is the Heatmap plot
plt.title('Weights in Germany\n based on binned cordinates', fontsize = 20) # title with fontsize 20
plt.xlabel('Latitudes', fontsize = 15) # x-axis label with fontsize 15
plt.ylabel('Longitudes', fontsize = 15) # y-axis label with fontsize 15
# Out:
# Text(114.0, 0.5, 'Longitudes')

# %%
normalized_df_min_max=(df-df.min())/(df.max()-df.min()) #min-max normalization

# %%
fig, ax = plt.subplots(figsize=(15,15))
ax = sns.heatmap(normalized_df_min_max, cmap='viridis') # Here is the Heatmap plot
plt.title('Weights in Germany\n based on binned cordinates', fontsize = 20) # title with fontsize 20
plt.xlabel('Latitudes', fontsize = 15) # x-axis label with fontsize 15
plt.ylabel('Longitudes', fontsize = 15) # y-axis label with fontsize 15
# Out:
# Text(114.0, 0.5, 'Longitudes')

# %%
# Out:
#   File "/tmp/ipykernel_91326/1229193320.py", line 1
#     pip3 freeze > requirements.txt
#          ^
# SyntaxError: invalid syntax
